# %%
import pandas as pd
pd.read_csv("therapist_pairs.csv")
# Out:
#                                                   query  \
# 0     So, basically, it's been getting a little bit ...
# 1     total four or five years, married for a year a...
# 2     I guess kind of once we got married after that...
# 3     It kind of Reminds me of how it used to be, yo...
# 4     this a little bit after. So, like I said, prob...
# ...                                                 ...
# 4812  I found out on Facebook, okay. Don't ask me wh...
# 4813  And I think all last year, I was doing tests, ...
# 4814  it was, it was better than 1000 mile service. ...
# 4815  Well, I think if you can do something for some...
# 4816  Yeah. Wow. Yeah. Yeah, that should be good. no...
#
#                                                response
# 0     Alright, so you're looking for independence in...
# 1     And when Franklin Did you notice that? What yo...
# 2     So you're looking for that freedom. Sarah, thi...
# 3     So, Sarah, Do you sense that and, frankly, fee...
# ...
